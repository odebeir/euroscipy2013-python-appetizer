# %%
from default import *
# Out:
# you are in -listener- mode

# %% [markdown]
# # Serial communication example

# %% [markdown]
# **Importing useful modules**

# %%
import serial
import serial.tools.list_ports as lp

# %% [markdown]
# **List of the available serial ports**

# %%
for port in lp.comports():
    print port
# Out:
# ('/dev/ttyS0', 'ttyS0', 'PNP0501')
# ('/dev/ttyS31', 'ttyS31', 'n/a')
# ('/dev/ttyS30', 'ttyS30', 'n/a')
# ('/dev/ttyS29', 'ttyS29', 'n/a')
# ('/dev/ttyS28', 'ttyS28', 'n/a')
# ('/dev/ttyS27', 'ttyS27', 'n/a')
# ('/dev/ttyS26', 'ttyS26', 'n/a')
# ('/dev/ttyS25', 'ttyS25', 'n/a')
# ('/dev/ttyS24', 'ttyS24', 'n/a')
# ('/dev/ttyS23', 'ttyS23', 'n/a')
# ('/dev/ttyS22', 'ttyS22', 'n/a')
# ('/dev/ttyS21', 'ttyS21', 'n/a')
# ('/dev/ttyS20', 'ttyS20', 'n/a')
# ('/dev/ttyS19', 'ttyS19', 'n/a')
# ('/dev/ttyS18', 'ttyS18', 'n/a')
# ('/dev/ttyS17', 'ttyS17', 'n/a')
# ('/dev/ttyS16', 'ttyS16', 'n/a')
# ('/dev/ttyS15', 'ttyS15', 'n/a')
# ('/dev/ttyS14', 'ttyS14', 'n/a')
# ('/dev/ttyS13', 'ttyS13', 'n/a')
# ('/dev/ttyS12', 'ttyS12', 'n/a')
# ('/dev/ttyS11', 'ttyS11', 'n/a')
# ('/dev/ttyS10', 'ttyS10', 'n/a')
# ('/dev/ttyS9', 'ttyS9', 'n/a')
# ('/dev/ttyS8', 'ttyS8', 'n/a')
# ('/dev/ttyS7', 'ttyS7', 'n/a')
# ('/dev/ttyS6', 'ttyS6', 'n/a')
# ('/dev/ttyS5', 'ttyS5', 'n/a')
# ('/dev/ttyS4', 'ttyS4', 'n/a')
# ('/dev/ttyS3', 'ttyS3', 'n/a')
# ('/dev/ttyS2', 'ttyS2', 'n/a')
# ('/dev/ttyS1', 'ttyS1', 'n/a')
# ('/dev/ttyACM0', 'ttyACM0', 'USB VID:PID=2341:0001 SNR=6493433323535101C161')

# %% [markdown]
# **Open serial communication**

# %%
ser = serial.Serial(port='/dev/ttyACM0', baudrate=115200, timeout=1,
                    bytesize=serial.EIGHTBITS, parity=serial.PARITY_NONE,stopbits=serial.STOPBITS_ONE,
                    dsrdtr=False,rtscts=False)
ser.setRtsCts(True)

# %%
print ser
# Out:
# Serial<id=0x3bbf1d0, open=True>(port='/dev/ttyACM0', baudrate=115200, bytesize=8, parity='N', stopbits=1, timeout=1, xonxoff=False, rtscts=True, dsrdtr=False)

# %% [markdown]
# **Get one sample**

# %%
ser.write('GET\n')
print ser.readline()
# Out:
# sensor: 674 3475

# %% [markdown]
# **Get more samples an plot a curve**

# %%
data = []
for i in range(10):
    ser.write('GET\n')
    line = ser.readline()
    s = line.split()
    data.append(s[1])
print data
# Out:
# ['553', '544', '524', '543', '557', '553', '540', '564', '571', '539']

# %%
plot(asarray(data))

# %%
#bigger exemple
rec = []
N = 400
for i in range(N):
    ser.write('GET\n')
    line = ser.readline()
    s = line.split()
    rec.append(float(s[1]))
f = asarray(rec)
plot(f)

# %%
F = fft.fft(f)

print F.dtype
# Out:
# complex128

# %%
plot(abs(F))

# %%
shifted_F = fft.fftshift(F)

plot(abs(shifted_F))

# %%
mask = zeros_like(F)
mask[N/2-50:N/2+50] = 1.0

shifted_filtered_F = shifted_F * mask

plot(abs(shifted_filtered_F))
plot(abs(shifted_F))

# %%
filtered_F = fft.ifftshift(shifted_filtered_F)

filtered_f = fft.ifft(filterd_F)

plot(abs(filtered_f))
plot(f)

# %% [markdown]
# **Close serial connection**

# %%
ser.close()
